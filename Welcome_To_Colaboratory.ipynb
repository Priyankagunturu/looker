# %% [markdown]
# <a href="https://colab.research.google.com/github/Priyankagunturu/looker/blob/main/Welcome_To_Colaboratory.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <h1>Welcome to Colab!</h1>
#
# If you're already familiar with Colab, check out this video to learn about interactive tables, the executed code history view, and the command palette.
#
# <center>
#   <a href="https://www.youtube.com/watch?v=rNgswRZ2C1Y" target="_blank">
#   <img alt='Thumbnail for a video showing 3 cool Google Colab features' src="data:image/png;base64,..." height="188" width="336">
#   </a>
# </center>

# %% [markdown]
# <h1>What is Colab?</h1>
#
# Colab, or "Colaboratory", allows you to write and execute Python in your browser, with
# - Zero configuration required
# - Access to GPUs free of charge
# - Easy sharing
#
# Whether you're a **student**, a **data scientist** or an **AI researcher**, Colab can make your work easier. Watch [Introduction to Colab](https://www.youtube.com/watch?v=inN8seMm7UI) to learn more, or just get started below!

# %% [markdown]
# ## **Getting started**
#
# The document you are reading is not a static web page, but an interactive environment called a **Colab notebook** that lets you write and execute code.
#
# For example, here is a **code cell** with a short Python script that computes a value, stores it in a variable, and prints the result:

# %%
seconds_in_a_day = 24 * 60 * 60
seconds_in_a_day
# Out:
# 86400

# %% [markdown]
# To execute the code in the above cell, select it with a click and then either press the play button to the left of the code, or use the keyboard shortcut "Command/Ctrl+Enter". To edit the code, just click the cell and start editing.
#
# Variables that you define in one cell can later be used in other cells:

# %%
seconds_in_a_week = 7 * seconds_in_a_day
seconds_in_a_week
# Out:
# 604800

# %% [markdown]
# Colab notebooks allow you to combine **executable code** and **rich text** in a single document, along with **images**, **HTML**, **LaTeX** and more. When you create your own Colab notebooks, they are stored in your Google Drive account. You can easily share your Colab notebooks with co-workers or friends, allowing them to comment on your notebooks or even edit them. To learn more, see [Overview of Colab](/notebooks/basic_features_overview.ipynb). To create a new Colab notebook you can use the File menu above, or use the following link: [create a new Colab notebook](http://colab.research.google.com#create=true).
#
# Colab notebooks are Jupyter notebooks that are hosted by Colab. To learn more about the Jupyter project, see [jupyter.org](https://www.jupyter.org).

# %% [markdown]
# ## Data science
#
# With Colab you can harness the full power of popular Python libraries to analyze and visualize data. The code cell below uses **numpy** to generate some random data, and uses **matplotlib** to visualize it. To edit the code, just click the cell and start editing.

# %%
import numpy as np
from matplotlib import pyplot as plt

ys = 200 + np.random.randn(100)
x = [x for x in range(len(ys))]

plt.plot(x, ys, '-')
plt.fill_between(x, ys, 195, where=(ys > 195), facecolor='g', alpha=0.6)

plt.title("Sample Visualization")
plt.show()

# %% [markdown]
# You can import your own data into Colab notebooks from your Google Drive account, including from spreadsheets, as well as from Github and many other sources. To learn more about importing data, and how Colab can be used for data science, see the links below under [Working with Data](#working-with-data).

# %% [markdown]
# ## Machine learning
#
# With Colab you can import an image dataset, train an image classifier on it, and evaluate the model, all in just [a few lines of code](https://colab.research.google.com/github/tensorflow/docs/blob/master/site/en/tutorials/quickstart/beginner.ipynb). Colab notebooks execute code on Google's cloud servers, meaning you can leverage the power of Google hardware, including [GPUs and TPUs](#using-accelerated-hardware), regardless of the power of your machine. All you need is a browser.

# %% [markdown]
# Colab is used extensively in the machine learning community with applications including:
# - Getting started with TensorFlow
# - Developing and training neural networks
# - Experimenting with TPUs
# - Disseminating AI research
# - Creating tutorials
#
# To see sample Colab notebooks that demonstrate machine learning applications, see the [machine learning examples](#machine-learning-examples) below.

# %% [markdown]
# ## More Resources
#
# ### Working with Notebooks in Colab
# - [Overview of Colaboratory](/notebooks/basic_features_overview.ipynb)
# - [Guide to Markdown](/notebooks/markdown_guide.ipynb)
# - [Importing libraries and installing dependencies](/notebooks/snippets/importing_libraries.ipynb)
# - [Saving and loading notebooks in GitHub](https://colab.research.google.com/github/googlecolab/colabtools/blob/main/notebooks/colab-github-demo.ipynb)
# - [Interactive forms](/notebooks/forms.ipynb)
# - [Interactive widgets](/notebooks/widgets.ipynb)
# - <img src="/img/new.png" height="20px" align="left" hspace="4px" alt="New"></img>
#  [TensorFlow 2 in Colab](/notebooks/tensorflow_version.ipynb)
#
# <a name="working-with-data"></a>
# ### Working with Data
# - [Loading data: Drive, Sheets, and Google Cloud Storage](/notebooks/io.ipynb)
# - [Charts: visualizing data](/notebooks/charts.ipynb)
# - [Getting started with BigQuery](/notebooks/bigquery.ipynb)
#
# ### Machine Learning Crash Course
# These are a few of the notebooks from Google's online Machine Learning course. See the [full course website](https://developers.google.com/machine-learning/crash-course/) for more.
# - [Intro to Pandas DataFrame](https://colab.research.google.com/github/google/eng-edu/blob/main/ml/cc/exercises/pandas_dataframe_ultraquick_tutorial.ipynb)
# - [Linear regression with tf.keras using synthetic data](https://colab.research.google.com/github/google/eng-edu/blob/main/ml/cc/exercises/linear_regression_with_synthetic_data.ipynb)
#
#
# <a name="using-accelerated-hardware"></a>
# ### Using Accelerated Hardware
# - [TensorFlow with GPUs](/notebooks/gpu.ipynb)
# - [TensorFlow with TPUs](/notebooks/tpu.ipynb)

# %% [markdown]
# <a name="machine-learning-examples"></a>
#
# ### Featured examples
#
# - [NeMo Voice Swap](https://colab.research.google.com/github/NVIDIA/NeMo/blob/stable/tutorials/VoiceSwapSample.ipynb): Use Nvidia's NeMo conversational AI Toolkit to swap a voice in an audio fragment with a computer generated one.
#
# - [Retraining an Image Classifier](https://tensorflow.org/hub/tutorials/tf2_image_retraining): Build a Keras model on top of a pre-trained image classifier to distinguish flowers.
# - [Text Classification](https://tensorflow.org/hub/tutorials/tf2_text_classification): Classify IMDB movie reviews as either *positive* or *negative*.
# - [Style Transfer](https://tensorflow.org/hub/tutorials/tf2_arbitrary_image_stylization): Use deep learning to transfer style between images.
# - [Multilingual Universal Sentence Encoder Q&A](https://tensorflow.org/hub/tutorials/retrieval_with_tf_hub_universal_encoder_qa): Use a machine learning model to answer questions from the SQuAD dataset.
# - [Video Interpolation](https://tensorflow.org/hub/tutorials/tweening_conv3d): Predict what happened in a video between the first and the last frame.

# %%
pip install looker-sdk
# Out:
#   File "<ipython-input-1-f17b4d93aa9b>", line 1
#     pip install looker-sdk
#               ^
# SyntaxError: invalid syntax

# %%
pip install looker_sdk
# Out:
# Collecting looker_sdk
#   Downloading looker_sdk-22.2.1-py3-none-any.whl (334 kB)
#      |████████████████████████████████| 334 kB 10.6 MB/s
# Requirement already satisfied: attrs>=20.1.0 in /usr/local/lib/python3.7/dist-packages (from looker_sdk) (21.4.0)
# Collecting typing-extensions>=4.1.1
#   Downloading typing_extensions-4.1.1-py3-none-any.whl (26 kB)
# Requirement already satisfied: requests>=2.22 in /usr/local/lib/python3.7/dist-packages (from looker_sdk) (2.23.0)
# Collecting cattrs>=1.3
#   Downloading cattrs-1.10.0-py3-none-any.whl (29 kB)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.22->looker_sdk) (2021.10.8)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.22->looker_sdk) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.22->looker_sdk) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.22->looker_sdk) (3.0.4)
# Installing collected packages: typing-extensions, cattrs, looker-sdk
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing-extensions 3.10.0.2
#     Uninstalling typing-extensions-3.10.0.2:
#       Successfully uninstalled typing-extensions-3.10.0.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.8.0 requires tf-estimator-nightly==2.8.0.dev2021122109, which is not installed.
# arviz 0.11.4 requires typing-extensions<4,>=3.7.4.3, but you have typing-extensions 4.1.1 which is incompatible.
# Successfully installed cattrs-1.10.0 looker-sdk-22.2.1 typing-extensions-4.1.1

# %%
pip install looker_sdk
# Out:
# Requirement already satisfied: looker_sdk in /usr/local/lib/python3.7/dist-packages (22.2.1)
# Requirement already satisfied: typing-extensions>=4.1.1 in /usr/local/lib/python3.7/dist-packages (from looker_sdk) (4.1.1)
# Requirement already satisfied: requests>=2.22 in /usr/local/lib/python3.7/dist-packages (from looker_sdk) (2.23.0)
# Requirement already satisfied: cattrs>=1.3 in /usr/local/lib/python3.7/dist-packages (from looker_sdk) (1.10.0)
# Requirement already satisfied: attrs>=20.1.0 in /usr/local/lib/python3.7/dist-packages (from looker_sdk) (21.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.22->looker_sdk) (2021.10.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.22->looker_sdk) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.22->looker_sdk) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.22->looker_sdk) (1.24.3)

# %%
import looker_sdk #Note that the pip install required a hyphen but the import is an underscore.

import os #We import os here in order to manage environment variables for the tutorial. You don't need to do this on a local system or anywhere you can more conveniently set environment variables.

import json #

# %%
# Base URL for API. Do not include /api/* in the url
base_url="https://trianz.looker.com:19999"
# API 3 client id
client_id="DBDW45JRcvdH2grbxyWb"
# API 3 client secret
client_secret="PNxXWq6CwJryZvMPfnc8Qvkj"
# Set to false if testing locally against self-signed certs. Otherwise leave True
verify_ssl=True

# %%
os.environ["LOOKERSDK_BASE_URL"] = "https://trianz.looker.com:19999" #If your looker URL has .cloud in it (hosted on GCP), do not include :19999 (ie: https://your.cloud.looker.com).
os.environ["LOOKERSDK_API_VERSION"] = "3.1" #3.1 is the default version. You can change this to 4.0 if you want.
os.environ["LOOKERSDK_VERIFY_SSL"] = "true" #Defaults to true if not set. SSL verification should generally be on unless you have a real good reason not to use it. Valid options: true, y, t, yes, 1.
os.environ["LOOKERSDK_TIMEOUT"] = "120" #Seconds till request timeout. Standard default is 120.

#Get the following values from your Users page in the Admin panel of your Looker instance > Users > Your user > Edit API keys. If you know your user id, you can visit https://your.looker.com/admin/users/<your_user_id>/edit.
os.environ["LOOKERSDK_CLIENT_ID"] =  "DBDW45JRcvdH2grbxyWb" #No defaults.
os.environ["LOOKERSDK_CLIENT_SECRET"] = "PNxXWq6CwJryZvMPfnc8Qvkj" #No defaults. This should be protected at all costs. Please do not leave it sitting here, even if you don't share this document.

print("All environment variables set.")
# Out:
# All environment variables set.

# %%
sdk = looker_sdk.init31()
print('Looker SDK 3.1 initialized successfully.')
# Out:
# Looker SDK 3.1 initialized successfully.

# %%
my_user = sdk.me()

#Output is an instance of the User model, but can also be read like a python dict. This applies to all Looker API calls that return Models.
#Example: The following commands return identical output. Feel free to use whichever style is more comfortable for you.

print(my_user.first_name) #Model dot notation
print(my_user["first_name"]) #Dictionary
# Out:
# Priyanka
# Priyanka

# %%
explore_id = "EEpMFLjNw1Lb6myHAgfrDk" 
#If your URL looks like https://your.cloud.looker.com/explore/ecommerce_data/order_items?qid=Q4pXny1FEtuxMuj9Atf0Gg&origin_space=15&toggle=vis, your explore_id/QID is Q4pXny1FEtuxMuj9Atf0Gg.
#https://trianz.looker.com/explore/thelook_partner/affinity?qid=EEpMFLjNw1Lb6myHAgfrDk&origin_space=149&toggle=vis
explore_query = sdk.query_for_slug(slug=explore_id) 
 #EEpMFLjNw1Lb6myHAgfrDk #1102,1103---look id's 30254, 30256--query id's 176-dashboard id
print(explore_query)
# Out:
# Query(model='thelook_partner', view='affinity', can={'run': True, 'see_results': True, 'explore': True, 'create': True, 'show': True, 'cost_estimate': True, 'index': True, 'see_lookml': True, 'see_aggregate_table_lookml': True, 'see_derived_table_lookml': True, 'see_sql': True, 'save': True, 'generate_drill_links': True, 'download': True, 'download_unlimited': True, 'use_custom_fields': True, 'schedule': True, 'render': True}, id=30401, fields=['product_a.item_name', 'product_b.item_name', 'affinity.avg_order_affinity', 'affinity.avg_user_affinity'], pivots=[], fill_fields=[], filters={'affinity.product_b_id': '-NULL', 'affinity.avg_order_affinity': 'NOT NULL', 'product_b.brand': '"Levi\'s"', 'product_a.brand': 'Calvin Klein'}, filter_expression='', sorts=['affinity.avg_order_affinity desc'], limit='15', column_limit='', total=None, row_total='', subtotals=[], vis_config={'show_view_names': False, 'show_row_numbers': True, 'transpose': False, 'truncate_text': True, 'hide_totals': False, 'hide_row_totals': False, 'size_to_fit': True, 'table_theme': 'white', 'limit_displayed_rows': False, 'enable_conditional_formatting': False, 'header_text_alignment': 'left', 'header_font_size': '12', 'rows_font_size': '12', 'conditional_formatting_include_totals': False, 'conditional_formatting_include_nulls': False, 'type': 'looker_grid', 'color_application': {'collection_id': 'b43731d5-dc87-4a8e-b807-635bef3948e7', 'palette_id': 'fb7bb53e-b77b-4ab6-8274-9d420d3d73f3', 'options': {'steps': 5, 'reverse': False, '__FILE': 'trianz_partner_bq/dashboards/brand_lookup.dashboard.lookml', '__LINE_NUM': 448}}, 'series_cell_visualizations': {'affinity.avg_order_affinity': {'is_active': True, 'palette': {'palette_id': '14bc3e56-1edb-5cb6-143e-bc3c0d49dc0f', 'collection_id': 'b43731d5-dc87-4a8e-b807-635bef3948e7', 'custom_colors': ['#f20265', '#FFD95F', '#72D16D'], '__FILE': 'trianz_partner_bq/dashboards/brand_lookup.dashboard.lookml', '__LINE_NUM': 454}, '__FILE': 'trianz_partner_bq/dashboards/brand_lookup.dashboard.lookml', '__LINE_NUM': 452}, 'affinity.avg_user_affinity': {'is_active': True, 'palette': {'palette_id': '8182e447-1db4-af27-fe8f-0cc57a1b4132', 'collection_id': 'b43731d5-dc87-4a8e-b807-635bef3948e7', 'custom_colors': ['#f20265', '#FFD95F', '#72D16D'], '__FILE': 'trianz_partner_bq/dashboards/brand_lookup.dashboard.lookml', '__LINE_NUM': 463}, '__FILE': 'trianz_partner_bq/dashboards/brand_lookup.dashboard.lookml', '__LINE_NUM': 461}}, 'stacking': '', 'trellis': '', 'colors': ['#57BEBE', '#EA8A2F', '#F2B431', '#64518A', '#8D7FB9', '#7F7977', '#B2A898', '#494C52'], 'show_value_labels': False, 'label_density': 25, 'legend_position': 'center', 'x_axis_gridlines': False, 'y_axis_gridlines': True, 'point_style': 'circle_outline', 'hidden_series': ['product_a.count', 'product_b.count'], 'y_axis_combined': True, 'show_y_axis_labels': True, 'show_y_axis_ticks': True, 'y_axis_tick_density': 'default', 'y_axis_tick_density_custom': 5, 'show_x_axis_label': True, 'show_x_axis_ticks': True, 'x_axis_scale': 'auto', 'y_axis_scale_mode': 'linear', 'x_axis_reversed': False, 'y_axis_reversed': False, 'plot_size_by_field': False, 'show_null_points': True, 'interpolation': 'linear', 'ordering': 'none', 'show_null_labels': False, 'color_palette': 'Custom', 'hidden_fields': [], 'series_types': {}, 'defaults_version': 1}, filter_config=None, visible_ui_sections='', slug='zmR84zC', dynamic_fields='', client_id='EEpMFLjNw1Lb6myHAgfrDk', share_url='https://trianz.looker.com/x/EEpMFLjNw1Lb6myHAgfrDk', expanded_share_url='https://trianz.looker.com/explore/thelook_partner/affinity?fields=product_a.item_name,product_b.item_name,affinity.avg_order_affinity,affinity.avg_user_affinity&f[affinity.product_b_id]=-NULL&f[affinity.avg_order_affinity]=NOT+NULL&f[product_b.brand]=%22Levi%27s%22&f[product_a.brand]=Calvin+Klein&sorts=affinity.avg_order_affinity+desc&limit=15&query_timezone=user_timezone&vis=%7B%22show_view_names%22%3Afalse%2C%22show_row_numbers%22%3Atrue%2C%22transpo ...

# %%
look_id = 282
look = sdk.look(look_id=look_id) 
# This gives us a Look object. We'll print the ID of it to verify everything's working.

print(look.id)
# Out:
# 282

# %%
try:
  response = sdk.run_look(
    look_id=look.id,
    result_format= "json" # Options here are csv, json, json_detail, txt, html, md, xlsx, sql (returns the raw query), png, jpg. JSON is the easiest to work with in python, so we return it.
  )
  data = json.loads(response) #The response is just a string, so we have to use the json library to load it as a json dict.
  print(data) #If our query was successful we should see an array of rows.
except:
  raise Exception(f'Error running look {look.id}')
# Out:
# [{'products.brand': ''}, {'products.brand': '!it Jeans'}, {'products.brand': '007Lingerie'}, {'products.brand': '10 Deep'}, {'products.brand': '106Shades'}, {'products.brand': '12XLShop Inc.'}, {'products.brand': '180s'}, {'products.brand': '1826'}, {'products.brand': '1WorldSarong'}, {'products.brand': '1veMoon'}, {'products.brand': '1vemoon'}, {'products.brand': '2(x)ist'}, {'products.brand': '2117 of Sweden'}, {'products.brand': '2XU'}, {'products.brand': '2b by bebe'}, {'products.brand': '35 Degree Below'}, {'products.brand': '4-rth'}, {'products.brand': '5 Seasons'}, {'products.brand': '525 America'}, {'products.brand': '555 Turnpike'}, {'products.brand': '55DSL'}, {'products.brand': '626 BLUE'}, {'products.brand': '66 North'}, {'products.brand': '7 Diamonds'}, {'products.brand': '7 For All Mankind'}, {'products.brand': '89th &#x0026; Madison'}, {'products.brand': 'A Pea in the Pod'}, {'products.brand': 'A shore Fit'}, {'products.brand': 'A. Byer'}, {'products.brand': 'A.B.S. by Allen Schwartz'}, {'products.brand': 'A:X Armani Exchange'}, {'products.brand': 'ADAR UNIFORMS'}, {'products.brand': 'ADVADRI'}, {'products.brand': 'AG Adriano Goldschmied'}, {'products.brand': 'AGB'}, {'products.brand': 'AJs'}, {'products.brand': 'ALL BLACK'}, {'products.brand': 'AN1225'}, {'products.brand': 'ANS'}, {'products.brand': 'ANSAI'}, {'products.brand': 'ARROW'}, {'products.brand': 'ASICS'}, {'products.brand': 'Abercrombie & Fitch'}, {'products.brand': 'Abini'}, {'products.brand': 'Active Products'}, {'products.brand': 'Activewear Apparel'}, {'products.brand': 'Acura'}, {'products.brand': 'Adi Designs'}, {'products.brand': 'Adriana'}, {'products.brand': 'Adrianna Papell'}, {'products.brand': 'Adventure Time'}, {'products.brand': 'Aegean'}, {'products.brand': 'Aerin Rose'}, {'products.brand': 'Aero Tech Designs'}, {'products.brand': 'Aeropostale'}, {'products.brand': 'Aerosoles'}, {'products.brand': 'Affazy'}, {'products.brand': 'Affinitas Intimates'}, {'products.brand': 'Affliction'}, {'products.brand': 'Aftco'}, {'products.brand': 'Agan Traders'}, {'products.brand': 'Agave'}, {'products.brand': 'Ahaarya'}, {'products.brand': 'Aimee Gowns'}, {'products.brand': 'Akademiks'}, {'products.brand': 'Akomplice'}, {'products.brand': 'Alan Sloane'}, {'products.brand': 'Alex Cannon'}, {'products.brand': 'Alex Evenings'}, {'products.brand': 'Alex Stevens'}, {'products.brand': 'Alexander Del Rossa'}, {'products.brand': 'Alexander Julian'}, {'products.brand': 'Alfani'}, {'products.brand': 'Alfred Dunner'}, {'products.brand': 'Alia'}, {'products.brand': 'Alice & Olivia'}, {'products.brand': 'Alice & Trixie'}, {'products.brand': 'Alivila.Y Fashion'}, {'products.brand': "Alki'i"}, {'products.brand': 'Allegra K'}, {'products.brand': 'Allen Allen'}, {'products.brand': 'Aloha'}, {'products.brand': 'Alpha Industries'}, {'products.brand': 'Alpine Swiss'}, {'products.brand': 'Alpinestars'}, {'products.brand': 'Altamont'}, {'products.brand': 'Alternative'}, {'products.brand': 'Always Sunny In Philadelphia'}, {'products.brand': 'Amanda Uprichard'}, {'products.brand': 'Amazing Apparel'}, {'products.brand': 'Ambiguous'}, {'products.brand': 'AmeriBag'}, {'products.brand': 'American Apparel'}, {'products.brand': 'American Essentials'}, {'products.brand': 'American Fighter'}, {'products.brand': 'American Rag'}, {'products.brand': 'Ames'}, {'products.brand': 'Amethyst Jeans'}, {'products.brand': 'Amicale'}, {'products.brand': 'Analog'}, {'products.brand': 'Andrew Christian'}, {'products.brand': 'Andrew Marc'}, {'products.brand': 'Anemone'}, {'products.brand': 'Angelina'}, {'products.brand': 'Angelina Hosiery'}, {'products.brand': 'Angry Birds'}, {'products.brand': 'Animal Planet'}, {'products.brand': 'AnimalShirtsUSA'}, {'products.brand': 'Anita'}, {'products.brand': 'Anna-Kaci'}, {'products.brand': 'Annabelle'}, {'products.brand': 'Annalee + Hope'}, {'products.brand': 'Anne Cole'}, {'products.brand': 'Anne Klein'}, {'products.brand': 'Annee Matthew'}, {'products.br ...

# %%
first_field = list(
    data[0].keys()
    )[0] #This looks at the first row of the data and returns the first field name. keys() returns a set, so we wrap it in list() to return an array.
    
for i in range(0,10):
  print(i,data[i][first_field])
# Out:
# 0
# 1 !it Jeans
# 2 007Lingerie
# 3 10 Deep
# 4 106Shades
# 5 12XLShop Inc.
# 6 180s
# 7 1826
# 8 1WorldSarong
# 9 1veMoon

# %%
import json

# %%
def get_data_for_look(look_id):
  try:
    look = sdk.look(look_id=look_id)
  except:
    raise Exception(f'Look {look_id} not found.')
  print(f'Successfully got Look {look.id}')

  try:
    response = sdk.run_look(
        look_id=look.id,
        result_format = "json"
    )
    data = json.loads(response)
    first_field = list(
      data[0].keys()
    )[0]
    list_of_values = []
    for i in data:
      list_of_values.append(i[first_field])
    #Ultimately, we're going to want to pass Looker a filter expression that's a comma-separated-list of values.
    #Here, we use .join on the array of values to generate that filter expression. 
    string_list = ",".join(list_of_values)
    return({"filter_values": string_list, "first_field": first_field}) 
  except:
    raise Exception('Error running Look.')

# %%
test = get_data_for_look(282)
# Out:
# Successfully got Look 282

# %%
second_look_id = 283
second_look = sdk.look(look_id=second_look_id)
print(second_look.id) #just verifying we obtained the Look properly.

#Now we can extract the underlying query from the second Look, in order to modify it. We'll print it to see what it looks like.
second_query = second_look.query
print(second_query)
# Out:
# 283
# Query(model='thelook_partner', view='order_items', can={'run': True, 'see_results': True, 'explore': True, 'create': True, 'show': True, 'cost_estimate': True, 'index': True, 'see_lookml': True, 'see_aggregate_table_lookml': True, 'see_derived_table_lookml': True, 'see_sql': True, 'save': True, 'generate_drill_links': True, 'download': True, 'download_unlimited': True, 'use_custom_fields': True, 'schedule': True, 'render': True}, id=30658, fields=['users.name', 'users.age'], pivots=None, fill_fields=None, filters={'order_items.order_count': '>1'}, filter_expression=None, sorts=['users.name'], limit='500', column_limit=None, total=None, row_total=None, subtotals=None, vis_config={'show_view_names': False, 'show_row_numbers': True, 'transpose': False, 'truncate_text': True, 'hide_totals': False, 'hide_row_totals': False, 'size_to_fit': True, 'table_theme': 'white', 'limit_displayed_rows': False, 'enable_conditional_formatting': False, 'header_text_alignment': 'left', 'header_font_size': 12, 'rows_font_size': 12, 'conditional_formatting_include_totals': False, 'conditional_formatting_include_nulls': False, 'type': 'looker_grid', 'defaults_version': 1}, filter_config={'order_items.order_count': [{'type': '>', 'values': [{'constant': '1'}, {}], 'id': 0, 'error': False}]}, visible_ui_sections=None, slug='BPQJ4zd', dynamic_fields=None, client_id='GaYqwXFFp9OmAsFJcEoBcs', share_url='https://trianz.looker.com/x/GaYqwXFFp9OmAsFJcEoBcs', expanded_share_url='https://trianz.looker.com/explore/thelook_partner/order_items?fields=users.name,users.age&f[order_items.order_count]=%3E1&sorts=users.name&limit=500&query_timezone=Asia%2FKolkata&vis=%7B%22show_view_names%22%3Afalse%2C%22show_row_numbers%22%3Atrue%2C%22transpose%22%3Afalse%2C%22truncate_text%22%3Atrue%2C%22hide_totals%22%3Afalse%2C%22hide_row_totals%22%3Afalse%2C%22size_to_fit%22%3Atrue%2C%22table_theme%22%3A%22white%22%2C%22limit_displayed_rows%22%3Afalse%2C%22enable_conditional_formatting%22%3Afalse%2C%22header_text_alignment%22%3A%22left%22%2C%22header_font_size%22%3A12%2C%22rows_font_size%22%3A12%2C%22conditional_formatting_include_totals%22%3Afalse%2C%22conditional_formatting_include_nulls%22%3Afalse%2C%22type%22%3A%22looker_grid%22%2C%22defaults_version%22%3A1%7D&filter_config=%7B%22order_items.order_count%22%3A%5B%7B%22type%22%3A%22%5Cu003e%22%2C%22values%22%3A%5B%7B%22constant%22%3A%221%22%7D%2C%7B%7D%5D%2C%22id%22%3A0%2C%22error%22%3Afalse%7D%5D%7D&origin=share-expanded', url='/explore/thelook_partner/order_items?fields=users.name,users.age&f[order_items.order_count]=%3E1&sorts=users.name&limit=500&query_timezone=Asia%2FKolkata&vis=%7B%22show_view_names%22%3Afalse%2C%22show_row_numbers%22%3Atrue%2C%22transpose%22%3Afalse%2C%22truncate_text%22%3Atrue%2C%22hide_totals%22%3Afalse%2C%22hide_row_totals%22%3Afalse%2C%22size_to_fit%22%3Atrue%2C%22table_theme%22%3A%22white%22%2C%22limit_displayed_rows%22%3Afalse%2C%22enable_conditional_formatting%22%3Afalse%2C%22header_text_alignment%22%3A%22left%22%2C%22header_font_size%22%3A12%2C%22rows_font_size%22%3A12%2C%22conditional_formatting_include_totals%22%3Afalse%2C%22conditional_formatting_include_nulls%22%3Afalse%2C%22type%22%3A%22looker_grid%22%2C%22defaults_version%22%3A1%7D&filter_config=%7B%22order_items.order_count%22%3A%5B%7B%22type%22%3A%22%5Cu003e%22%2C%22values%22%3A%5B%7B%22constant%22%3A%221%22%7D%2C%7B%7D%5D%2C%22id%22%3A0%2C%22error%22%3Afalse%7D%5D%7D', query_timezone='Asia/Kolkata', has_table_calculations=False, runtime=None)

# %%
print(second_query.keys())
# Out:
# dict_keys(['model', 'view', 'can', 'id', 'fields', 'filters', 'sorts', 'limit', 'vis_config', 'filter_config', 'slug', 'client_id', 'share_url', 'expanded_share_url', 'url', 'query_timezone', 'has_table_calculations'])

# %%
print("Filters: ", second_query.filters)
# Out:
# Filters:  {'order_items.order_count': '>1'}

# %%
response = sdk.run_query(query_id = second_query.id, result_format="json")
print(response)
# Out:
# [{"users.name":"Aaron Anderson","users.age":14},
# {"users.name":"Aaron Atkins","users.age":22},
# {"users.name":"Aaron Beardsley","users.age":68},
# {"users.name":"Aaron Beavers","users.age":16},
# {"users.name":"Aaron Best","users.age":12},
# {"users.name":"Aaron Binder","users.age":32},
# {"users.name":"Aaron Blakeney","users.age":58},
# {"users.name":"Aaron Bobb","users.age":43},
# {"users.name":"Aaron Bock","users.age":49},
# {"users.name":"Aaron Brush","users.age":52},
# {"users.name":"Aaron Cheek","users.age":14},
# {"users.name":"Aaron Collado","users.age":30},
# {"users.name":"Aaron Delossantos","users.age":28},
# {"users.name":"Aaron Felton","users.age":12},
# {"users.name":"Aaron Fletcher","users.age":93},
# {"users.name":"Aaron Frazier","users.age":47},
# {"users.name":"Aaron Garcia","users.age":48},
# {"users.name":"Aaron Hampton","users.age":67},
# {"users.name":"Aaron Harrill","users.age":71},
# {"users.name":"Aaron Hart","users.age":38},
# {"users.name":"Aaron Haywood","users.age":38},
# {"users.name":"Aaron Holeman","users.age":51},
# {"users.name":"Aaron Horn","users.age":26},
# {"users.name":"Aaron Hudgens","users.age":16},
# {"users.name":"Aaron Johnson","users.age":42},
# {"users.name":"Aaron Kelly","users.age":61},
# {"users.name":"Aaron Lane","users.age":12},
# {"users.name":"Aaron Lawrence","users.age":72},
# {"users.name":"Aaron Lightle","users.age":73},
# {"users.name":"Aaron Livingston","users.age":61},
# {"users.name":"Aaron Madden","users.age":12},
# {"users.name":"Aaron Malley","users.age":72},
# {"users.name":"Aaron Marshall","users.age":44},
# {"users.name":"Aaron May","users.age":67},
# {"users.name":"Aaron Mccullough","users.age":16},
# {"users.name":"Aaron Mcginnis","users.age":12},
# {"users.name":"Aaron Mcgovern","users.age":46},
# {"users.name":"Aaron Meza","users.age":61},
# {"users.name":"Aaron Mills","users.age":72},
# {"users.name":"Aaron Mirabal","users.age":16},
# {"users.name":"Aaron Mosley","users.age":44},
# {"users.name":"Aaron Myers","users.age":58},
# {"users.name":"Aaron Newman","users.age":14},
# {"users.name":"Aaron Nicholson","users.age":12},
# {"users.name":"Aaron Quintana","users.age":58},
# {"users.name":"Aaron Rader","users.age":12},
# {"users.name":"Aaron Richards","users.age":32},
# {"users.name":"Aaron Rivera","users.age":20},
# {"users.name":"Aaron Sanchez","users.age":72},
# {"users.name":"Aaron Scott","users.age":37},
# {"users.name":"Aaron Smartt","users.age":62},
# {"users.name":"Aaron Smith","users.age":39},
# {"users.name":"Aaron Stewart","users.age":33},
# {"users.name":"Aaron Stokes","users.age":41},
# {"users.name":"Aaron Swafford","users.age":46},
# {"users.name":"Aaron Szymanski","users.age":38},
# {"users.name":"Aaron Taylor","users.age":27},
# {"users.name":"Aaron Thomas","users.age":41},
# {"users.name":"Aaron Traylor","users.age":62},
# {"users.name":"Aaron Vasquez","users.age":39},
# {"users.name":"Aaron Ward","users.age":64},
# {"users.name":"Abbie Chun","users.age":46},
# {"users.name":"Abbie Hance","users.age":12},
# {"users.name":"Abbie Moats","users.age":61},
# {"users.name":"Abby Harris","users.age":37},
# {"users.name":"Abby Kight","users.age":38},
# {"users.name":"Abby Moore","users.age":47},
# {"users.name":"Abby Reynolds","users.age":61},
# {"users.name":"Abdul Armstrong","users.age":72},
# {"users.name":"Abe Friedman","users.age":16},
# {"users.name":"Abel Ackman","users.age":23},
# {"users.name":"Abel Hamrick","users.age":14},
# {"users.name":"Abel Johnson","users.age":49},
# {"users.name":"Abel Mayes","users.age":14},
# {"users.name":"Abel Rodriguez","users.age":48},
# {"users.name":"Abigail Kwak","users.age":81},
# {"users.name":"Abigail Pringle","users.age":16},
# {"users.name":"Abraham Gonzalez","users.age":14},
# {"users.name":"Abraham Ruiz","users.age":51},
# {"users.name":"Abraham Zamudio","users.age":49},
# {"users.name":"Abram Judkins","users.age":57},
# {"users.name":"Ada Buell","users.age":38},
# {"users.name":"Ada Canales","users.age":28},
# {"users.name":"Ada Compton","users.age":58},
# {"users.name":"Ada English","users.age":36},
# {"users.name":"Ada Giltner","users.age":62},
# {"users.name":"Ada Hall","users.age":48},
# {"users.name":"Ada Kiser","users.age":39},
# {"users.name":"Ada Smith","users.age":42},
# {"users.name":"Ada Stephens","users.age":51},
# {"users.name":"Ada Velez","users.age":38},
# {"users.name":"Adah Jenkins","users.age":64},
# {"users.name":"Adalberto Mahone","users.age":12},
# {"users.name":"Adam Anderson","users.age":83},
# {"users.name":"Adam Barnum","users.age":25},
# {"users.name":"Adam Barrientos","users.age":38},
# {"users.name":"Adam Berggren","users.age":39},
# {"users.name":"Adam Blackwood","users.age":59},
# {"users.name":"Adam Bradley","users.age":25},
# {"users.name":"Adam Braswell","users.age":53},
# {"users.name":"Adam Castillo","users.age":88},
# {"users.name":"Adam Collins","users.age":34},
# {"users.name":"Adam Conner","users.age":44},
# {"users.name":"Adam Davenport","users.age":29},
# {"users.name":"Adam Day","users.age":14},
# {"users.name":"Adam Dufour","users.age":57},
# {"users.name":"Adam Duncan","users.age":43},
# {"users.name":"Adam Ferguson","users.age":12},
# {"users.name":"Adam Fitzgerald","users.age":37},
# {"users.name":"Adam Frank","users.age":73},
# {"users.name":"Adam Fulcher","users.age":46},
# {"users.name":"Adam Gonzales","users.age":49},
# {"users.name":"Adam Graham","users.age":38},
# {"users.name":"Adam Grisham","users.age":53},
# {"users.name":"Adam Harlow","users.age":42},
# {"users.name":"Adam Hodges","users.age":53},
# {"users.name":"Adam Irvin","users.age":14},
# {"users.name":"Adam Jensen","users.age":12},
# {"users.name":"Adam Krone","users.age":30},
# {"users.name":"Adam Leahy","users.age":54},
# {"users.name":"Adam Mansfield","users.age":59},
# {"users.name":"Adam Marshall","users.age":49},
# {"users.name":"Adam Martin","users.age":44},
# {"users.name":"Adam Martinez","users.age":51},
# {"users.name":"Adam Mcgowan","users.age":12},
# {"users.name":"Adam Michael","users.age":53},
# {"users.name":"Adam Moreno","users.age":58},
# {"users.name":"Adam Munguia","users.age":12},
# {"users.name":"Adam Pardo","users.age":44},
# {"users.name":"Adam Peterson","users.age":23},
# {"users.name":"Adam Pineda","users.age":62},
# {"users.name":"Adam Polk","users.age":14},
# {"users.name":"Adam Purtell","users.age":64},
# {"users.name":"Adam Ramos","users.age":16},
# {"users.name":"Adam Ray","users.age":12},
# {"users.name":"Adam Rodriguez","users.age":38},
# {"users.name":"Adam Shumway","users.age":14},
# {"users.name":"Adam Smith","users.age":62},
# {"users.name":"Adam Stephens","users.age":53},
# {"users.name":"Adam Thomas","users.age":42},
# {"users.name":"Adam Thorpe","users.age":37},
# {"users.name":"Adam Torres","users.age":89},
# {"users.name":"Adam Warner","users.age":47},
# {"users.name":"Adam Williams","users.age":29},
# {"users.name":"Adam Winslow","users.age":67},
# {"users.name":"Adam Winston","users.age":48},
# {"users.name":"Adam Zuniga","users.age":93},
# {"users.name":"Adan Arcand","users.age":39},
# {"users.name":"Adan Mccleskey","users.age":27},
# {"users.name":"Adan Platt","users.age":47},
# {"users.name":"Addie Downey","users.age":12},
# {"users.name":"Addie Garrett","users.age":19},
# {"users.name":"Addie Miller","users.age":21},
# {"users.name":"Addie Murphy","users.age":38},
# {"users.name":"Addie Paulson","users.age":16},
# {"users.name":"Addie Powe","users.age":18},
# {"users.name":"Addie Rogers","users.age":44},
# {"users.name":"Addie Smith","users.age":46},
# {"users.name":"Addie Twigg","users.age":41},
# {"users.name":"Addie White","users.age":54},
# {"users.name":"Adela Cloer","users.age":16},
# {"users.name":"Adela Douglas","users.age":49},
# {"users.name":"Adela Pollack","users.age":18},
# {"users.name":"Adela Smith","users.age":63},
# {"users.name":"Adelaida Wood","users.age":14},
# {"users.name":"Adelaida Young","users.age":14},
# {"users.name":"Adelaide Feller","users.age":41},
# {"users.name":"Adelaide Johnson","users.age":16},
# {"users.name":"Adelaide Krum","users.age":54},
# {"users.name":"Adelaide Sales","users.age":36},
# {"users.name":"Adelaide Snow","users.age":37},
# {"users.name":"Adele Anglin","users.age":37},
# {"users.name":"Adele Baldwin","users.age":43},
# {"users.name":"Adele Collins","users.age":42},
# {"users.name":"Adele Ferguson","users.age":62},
# {"users.name":"Adele Flowers","users.age":63},
# {"users.name":"Adele Herr","users.age":59},
# {"users.name":"Adele Milliken","users.age":43},
# {"users.name":"Adele Oliva","users.age":77},
# {"users.name":"Adele Salazar","users.age":36},
# {"users.name":"Adele Shelton","users.age":48},
# {"users.name":"Adele Wood","users.age":14},
# {"users.name":"Adelina Aguilar","users.age":12},
# {"users.name":"Adelina Cox","users.age":14},
# {"users.name":"Adelina Patton","users.age":41},
# {"users.name":"Adeline Griffith","users.age":42},
# {"users.name":"Adeline Huizenga","users.age":43},
# {"users.name":"Adeline Ortiz","users.age":14},
# {"users.name":"Adell Agan","users.age":14},
# {"users.name":"Adell Tracy","users.age":36},
# {"users.name":"Adella Howard","users.age":38},
# {"users.name":"Adelle Coughlin","users.age":28},
# {"users.name":"Adolfo Boehm","users.age":14},
# {"users.name":"Adolfo Fleetwood","users.age":32},
# {"users.name":"Adolfo Johnson","users.age":51},
# {"users.name":"Adolfo Kemp","users.age":36},
# {"users.name":"Adolfo Murphy","users.age":42},
# {"users.name":"Adolph Brough","users.age":54},
# {"users.name":"Adolph Phillips","users.age":53},
# {"users.name":"Adolph Taylor","users.age":30},
# {"users.name":"Adria Greenwood","users.age":46},
# {"users.name":"Adria Jenkins","users.age":71},
# {"users.name":"Adrian Black","users.age":38},
# {"users.name":"Adrian Freeman","users.age":41},
# {"users.name":"Adrian Fuller","users.age":14},
# {"users.name":"Adrian Gonzales","users.age":64},
# {"users.name":"Adrian Gross","users.age":44},
# {"users.name":"Adrian Halpin","users.age":46},
# {"users.name":"Adrian Knaus","users.age":12},
# {"users.name":"Adrian Mckenzie","users.age":19},
# {"users.name":"Adrian Miller","users.age":36},
# {"users.name":"Adrian Morabito","users.age":37},
# {"users.name":"Adrian Obannon","users.age":44},
# {"users.name":"Adrian Ohara","users.age":32},
# {"users.name":"Adrian Raffa","users.age":44},
# {"users.name":"Adrian Scott","users.age":46},
# {"users.name":"Adrian Shaw","users.age":53},
# {"users.name":"Adrian Small","users.age":59},
# {"users.name":"Adrian Ware","users.age":44},
# {"users.name":"Adrian Watson","users.age":68},
# {"users.name":"Adrian White","users.age":26},
# {"users.name":"Adriana Coleman","users.age":88},
# {"users.name":"Adriana Davis","users.age":41},
# {"users.name":"Adriana Foster","users.age":26},
# {"users.name":"Adriana Leach","users.age":42},
# {"users.name":"Adriana Luong","users.age":12},
# {"users.name":"Adriana Nilson","users.age":38},
# {"users.name":"Adriana Weber","users.age":56},
# {"users.name":"Adriane Freeman","users.age":101},
# {"users.name":"Adrianna Short","users.age":39},
# {"users.name":"Adrianna Stanton","users.age":54},
# {"users.name":"Adrianne Wheeler","users.age":16},
# {"users.name":"Adrien Giles","users.age":53},
# {"users.name":"Adrienne Brown","users.age":54},
# {"users.name":"Adrienne Gokey","users.age":51},
# {"users.name":"Adrienne Madrid","users.age":59},
# {"users.name":"Adrienne Obrien","users.age":64},
# {"users.name":"Adrienne Patterson","users.age":16},
# {"users.name":"Adrienne Rodriguez","users.age":69},
# {"users.name":"Adrienne Torres","users.age":38},
# {"users.name":"Adrienne Winebrenner","users.age":38},
# {"users.name":"Afton Long","users.age":49},
# {"users.name":"Agatha Payne","users.age":14},
# {"users.name":"Agnes Allen","users.age":14},
# {"users.name":"Agnes Baumann","users.age":62},
# {"users.name":"Agnes Casey","users.age":63},
# {"users.name":"Agnes Chase","users.age":32},
# {"users.name":"Agnes Garrett","users.age":32},
# {"users.name":"Agnes Hague","users.age":39},
# {"users.name":"Agnes Hale","users.age":18},
# {"users.name":"Agnes Henry","users.age":14},
# {"users.name":"Agnes Hernandez","users.age":46},
# {"users.name":"Agnes Hewitt","users.age":12},
# {"users.name":"Agnes Hodges","users.age":14},
# {"users.name":"Agnes Holland","users.age":54},
# {"users.name":"Agnes Jarboe","users.age":42},
# {"users.name":"Agnes Johnson","users.age":26},
# {"users.name":"Agnes Jones","users.age":41},
# {"users.name":"Agnes Landry","users.age":70},
# {"users.name":"Agnes Lassiter","users.age":32},
# {"users.name":"Agnes Leggett","users.age":37},
# {"users.name":"Agnes Loving","users.age":73},
# {"users.name":"Agnes Mckinney","users.age":21},
# {"users.name":"Agnes Mullen","users.age":56},
# {"users.name":"Agnes Norris","users.age":16},
# {"users.name":"Agnes Roundtree","users.age":36},
# {"users.name":"Agnes Solis","users.age":14},
# {"users.name":"Agnes Straight","users.age":49},
# {"users.name":"Agnes Turner","users.age":46},
# {"users.name":"Agnes Vargas","users.age":74},
# {"users.name":"Agnes Whitehead","users.age":41},
# {"users.name":"Agnes Williams","users.age":37},
# {"users.name":"Agnes Zanders","users.age":61},
# {"users.name":"Agustin Cardenas","users.age":16},
# {"users.name":"Agustin Farris","users.age":44},
# {"users.name":"Agustin Lingerfelt","users.age":14},
# {"users.name":"Agustin Little","users.age":36},
# {"users.name":"Agustin Parrish","users.age":16},
# {"users.name":"Ahmed Bradley","users.age":26},
# {"users.name":"Aida Allen","users.age":12},
# {"users.name":"Aida Andrews","users.age":42},
# {"users.name":"Aida Blizzard","users.age":42},
# {"users.name":"Aida Britten","users.age":23},
# {"users.name":"Aida Farrow","users.age":43},
# {"users.name":"Aida Jones","users.age":12},
# {"users.name":"Aida Miles","users.age":94},
# {"users.name":"Aida Nelson","users.age":53},
# {"users.name":"Aida Thomas","users.age":46},
# {"users.name":"Aileen Carter","users.age":46},
# {"users.name":"Aimee Bennett","users.age":48},
# {"users.name":"Aimee Garcia","users.age":27},
# {"users.name":"Aimee Hoyer","users.age":78},
# {"users.name":"Aisha Alvarez","users.age":92},
# {"users.name":"Aisha Devore","users.age":46},
# {"users.name":"Aisha Goodman","users.age":97},
# {"users.name":"Akiko Griswold","users.age":42},
# {"users.name":"Akiko Wright","users.age":16},
# {"users.name":"Akilah Gilbert","users.age":48},
# {"users.name":"Al Aaron","users.age":51},
# {"users.name":"Al Hayden","users.age":14},
# {"users.name":"Al Steed","users.age":16},
# {"users.name":"Al Wing","users.age":18},
# {"users.name":"Alaina Gunter","users.age":57},
# {"users.name":"Alaina Lett","users.age":46},
# {"users.name":"Alan Alford","users.age":57},
# {"users.name":"Alan Anderson","users.age":42},
# {"users.name":"Alan Brooks","users.age":16},
# {"users.name":"Alan Brunson","users.age":44},
# {"users.name":"Alan Bryant","users.age":52},
# {"users.name":"Alan Chang","users.age":12},
# {"users.name":"Alan Coleman","users.age":36},
# {"users.name":"Alan Connally","users.age":62},
# {"users.name":"Alan Cotner","users.age":12},
# {"users.name":"Alan Dall","users.age":39},
# {"users.name":"Alan Davis","users.age":26},
# {"users.name":"Alan Deblois","users.age":19},
# {"users.name":"Alan Donovan","users.age":22},
# {"users.name":"Alan Edwards","users.age":57},
# {"users.name":"Alan Fife","users.age":52},
# {"users.name":"Alan Flaherty","users.age":36},
# {"users.name":"Alan Franco","users.age":37},
# {"users.name":"Alan Gallegos","users.age":37},
# {"users.name":"Alan Garner","users.age":14},
# {"users.name":"Alan Gibbs","users.age":12},
# {"users.name":"Alan Gibson","users.age":16},
# {"users.name":"Alan Gonzalez","users.age":14},
# {"users.name":"Alan Haines","users.age":23},
# {"users.name":"Alan Hanson","users.age":12},
# {"users.name":"Alan Hardy","users.age":63},
# {"users.name":"Alan Hernandez","users.age":64},
# {"users.name":"Alan Jones","users.age":86},
# {"users.name":"Alan Jones","users.age":37},
# {"users.name":"Alan Koenig","users.age":14},
# {"users.name":"Alan Kruger","users.age":53},
# {"users.name":"Alan Lamar","users.age":12},
# {"users.name":"Alan Lassiter","users.age":46},
# {"users.name":"Alan Manning","users.age":43},
# {"users.name":"Alan Martin","users.age":64},
# {"users.name":"Alan Melancon","users.age":39},
# {"users.name":"Alan Mills","users.age":59},
# {"users.name":"Alan Moore","users.age":38},
# {"users.name":"Alan Murray","users.age":42},
# {"users.name":"Alan Navarette","users.age":64},
# {"users.name":"Alan Oliver","users.age":53},
# {"users.name":"Alan Pagano","users.age":25},
# {"users.name":"Alan Parker","users.age":16},
# {"users.name":"Alan Perry","users.age":44},
# {"users.name":"Alan Rabinowitz","users.age":12},
# {"users.name":"Alan Rice","users.age":61},
# {"users.name":"Alan Rodrigez","users.age":49},
# {"users.name":"Alan Rogers","users.age":14},
# {"users.name":"Alan Sherry","users.age":38},
# {"users.name":"Alan Siegel","users.age":18},
# {"users.name":"Alan Spahn","users.age":16},
# {"users.name":"Alan Stanton","users.age":43},
# {"users.name":"Alan Swindell","users.age":31},
# {"users.name":"Alan Tarbell","users.age":12},
# {"users.name":"Alan Taylor","users.age":58},
# {"users.name":"Alan Tu","users.age":37},
# {"users.name":"Alan Walker","users.age":12},
# {"users.name":"Alan Williams","users.age":36},
# {"users.name":"Alan Won","users.age":62},
# {"users.name":"Alana Newell","users.age":70},
# {"users.name":"Alana Quintero","users.age":58},
# {"users.name":"Alana Santillan","users.age":38},
# {"users.name":"Alana Wilson","users.age":48},
# {"users.name":"Alayna Harvey","users.age":14},
# {"users.name":"Alayna Horsley","users.age":41},
# {"users.name":"Alba Lessard","users.age":12},
# {"users.name":"Albert Allen","users.age":25},
# {"users.name":"Albert Atkinson","users.age":16},
# {"users.name":"Albert Austin","users.age":42},
# {"users.name":"Albert Benn","users.age":42},
# {"users.name":"Albert Black","users.age":38},
# {"users.name":"Albert Blake","users.age":14},
# {"users.name":"Albert Branton","users.age":16},
# {"users.name":"Albert Camp","users.age":101},
# {"users.name":"Albert Carlson","users.age":49},
# {"users.name":"Albert Caron","users.age":34},
# {"users.name":"Albert Carroll","users.age":48},
# {"users.name":"Albert Cox","users.age":38},
# {"users.name":"Albert Cox","users.age":74},
# {"users.name":"Albert Crawley","users.age":44},
# {"users.name":"Albert David","users.age":86},
# {"users.name":"Albert Diaz","users.age":92},
# {"users.name":"Albert Dodds","users.age":53},
# {"users.name":"Albert Dunne","users.age":49},
# {"users.name":"Albert Elliott","users.age":56},
# {"users.name":"Albert Enders","users.age":63},
# {"users.name":"Albert Finley","users.age":53},
# {"users.name":"Albert Fisher","users.age":51},
# {"users.name":"Albert Franklin","users.age":14},
# {"users.name":"Albert Gaines","users.age":14},
# {"users.name":"Albert Galindo","users.age":31},
# {"users.name":"Albert Garcia","users.age":98},
# {"users.name":"Albert Gay","users.age":12},
# {"users.name":"Albert Hackman","users.age":12},
# {"users.name":"Albert Holcomb","users.age":47},
# {"users.name":"Albert Hollander","users.age":38},
# {"users.name":"Albert Houle","users.age":93},
# {"users.name":"Albert Hunt","users.age":43},
# {"users.name":"Albert Jordan","users.age":46},
# {"users.name":"Albert Jowers","users.age":38},
# {"users.name":"Albert Keeney","users.age":59},
# {"users.name":"Albert Kelley","users.age":51},
# {"users.name":"Albert Kelly","users.age":43},
# {"users.name":"Albert King","users.age":44},
# {"users.name":"Albert Kyle","users.age":49},
# {"users.name":"Albert Lawson","users.age":82},
# {"users.name":"Albert Mann","users.age":12},
# {"users.name":"Albert Matter","users.age":41},
# {"users.name":"Albert Mcnally","users.age":72},
# {"users.name":"Albert Monahan","users.age":49},
# {"users.name":"Albert Owens","users.age":32},
# {"users.name":"Albert Pardue","users.age":46},
# {"users.name":"Albert Paul","users.age":64},
# {"users.name":"Albert Pena","users.age":37},
# {"users.name":"Albert Powell","users.age":41},
# {"users.name":"Albert Ramirez","users.age":57},
# {"users.name":"Albert Rawlings","users.age":49},
# {"users.name":"Albert Ray","users.age":16},
# {"users.name":"Albert Ronan","users.age":101},
# {"users.name":"Albert Ross","users.age":12},
# {"users.name":"Albert Salazar","users.age":37},
# {"users.name":"Albert Salinas","users.age":16},
# {"users.name":"Albert Sandberg","users.age":12},
# {"users.name":"Albert Sanders","users.age":53},
# {"users.name":"Albert Scott","users.age":12},
# {"users.name":"Albert Simpson","users.age":14},
# {"users.name":"Albert Smith","users.age":42},
# {"users.name":"Albert Smith","users.age":14},
# {"users.name":"Albert Stratton","users.age":37},
# {"users.name":"Albert Thoreson","users.age":21},
# {"users.name":"Albert Travis","users.age":36},
# {"users.name":"Albert Vance","users.age":12},
# {"users.name":"Albert Wade","users.age":57},
# {"users.name":"Albert Wakefield","users.age":30},
# {"users.name":"Albert Willis","users.age":16},
# {"users.name":"Albert Wright","users.age":51},
# {"users.name":"Albert Yates","users.age":57},
# {"users.name":"Albert Young","users.age":53},
# {"users.name":"Alberta Allen","users.age":68},
# {"users.name":"Alberta Alvarez","users.age":41},
# {"users.name":"Alberta Fenn","users.age":12},
# {"users.name":"Alberta Fisher","users.age":39},
# {"users.name":"Alberta Galbraith","users.age":16},
# {"users.name":"Alberta Henninger","users.age":49},
# {"users.name":"Alberta Howard","users.age":28},
# {"users.name":"Alberta Leavitt","users.age":47},
# {"users.name":"Alberta Lee","users.age":52},
# {"users.name":"Alberta Lundy","users.age":36},
# {"users.name":"Alberta Maynor","users.age":62},
# {"users.name":"Alberta Mueller","users.age":41},
# {"users.name":"Alberta Paschke","users.age":49},
# {"users.name":"Alberta Richardson","users.age":32},
# {"users.name":"Alberta Richardson","users.age":49},
# {"users.name":"Alberta Saldana","users.age":61},
# {"users.name":"Alberta Urbina","users.age":25},
# {"users.name":"Alberta Weight","users.age":48},
# {"users.name":"Alberta Williams","users.age":64},
# {"users.name":"Alberta Winnie","users.age":25},
# {"users.name":"Albertina Collinson","users.age":16},
# {"users.name":"Alberto Barnes","users.age":16},
# {"users.name":"Alberto Baum","users.age":16},
# {"users.name":"Alberto Calhoun","users.age":43},
# {"users.name":"Alberto Davis","users.age":46},
# {"users.name":"Alberto Delia","users.age":41},
# {"users.name":"Alberto Fortney","users.age":28},
# {"users.name":"Alberto Friedman","users.age":12},
# {"users.name":"Alberto Graham","users.age":38},
# {"users.name":"Alberto Hearn","users.age":16},
# {"users.name":"Alberto Johnson","users.age":39},
# {"users.name":"Alberto Leger","users.age":38},
# {"users.name":"Alberto Levy","users.age":38},
# {"users.name":"Alberto Meeks","users.age":86},
# {"users.name":"Alberto Turner","users.age":12},
# {"users.name":"Alberto Valladares","users.age":14},
# {"users.name":"Alberto White","users.age":16},
# {"users.name":"Alberto Williams","users.age":39},
# {"users.name":"Alberto Woodard","users.age":39},
# {"users.name":"Albina Salazar","users.age":42},
# {"users.name":"Alden Overbeck","users.age":53},
# {"users.name":"Aldo Lilley","users.age":41},
# {"users.name":"Aldo Trombly","users.age":34},
# {"users.name":"Alec Hurtado","users.age":14},
# {"users.name":"Alecia Hoffman","users.age":49},
# {"users.name":"Alejandra Cates","users.age":14},
# {"users.name":"Alejandra Jan","users.age":42},
# {"users.name":"Alejandra Ortega","users.age":36},
# {"users.name":"Alejandra Pace","users.age":43},
# {"users.name":"Alejandra Rothschild","users.age":27},
# {"users.name":"Alejandra Wilson","users.age":58},
# {"users.name":"Alejandro Acosta","users.age":41},
# {"users.name":"Alejandro Barraza","users.age":58},
# {"users.name":"Alejandro Crawford","users.age":12},
# {"users.name":"Alejandro Evens","users.age":49},
# {"users.name":"Alejandro Lewis","users.age":16},
# {"users.name":"Alejandro Lopez","users.age":79},
# {"users.name":"Alejandro Marchand","users.age":36},
# {"users.name":"Alejandro Myles","users.age":16}]

# %%
#Let's create a new variable, altered_query, and assign it to be identical to second_query to begin.
altered_query = second_query 

#Then, let's set a new key on the filters dict, which adds a new filter to the query. We'll name it the name of the field we want to filter on.
#This must exactly match the **fully scoped** field name in Looker (ie: view_name.field_name).
#We will then set that key's value equal to our data. In this case, we'll set it equal to that comma-separated string we generated earlier.

filter_data = get_data_for_look(282) # This is that function we built earlier.
field_name = filter_data['first_field']
filter_values = filter_data['filter_values']

altered_query.filters[field_name] = filter_values

#This should now print an object with the filters you've just added. Nice!
print(altered_query.filters)
# Out:
# Successfully got Look 282
# {'order_items.order_count': '>1', 'products.brand': ",!it Jeans,007Lingerie,10 Deep,106Shades,12XLShop Inc.,180s,1826,1WorldSarong,1veMoon,1vemoon,2(x)ist,2117 of Sweden,2XU,2b by bebe,35 Degree Below,4-rth,5 Seasons,525 America,555 Turnpike,55DSL,626 BLUE,66 North,7 Diamonds,7 For All Mankind,89th &#x0026; Madison,A Pea in the Pod,A shore Fit,A. Byer,A.B.S. by Allen Schwartz,A:X Armani Exchange,ADAR UNIFORMS,ADVADRI,AG Adriano Goldschmied,AGB,AJs,ALL BLACK,AN1225,ANS,ANSAI,ARROW,ASICS,Abercrombie & Fitch,Abini,Active Products,Activewear Apparel,Acura,Adi Designs,Adriana,Adrianna Papell,Adventure Time,Aegean,Aerin Rose,Aero Tech Designs,Aeropostale,Aerosoles,Affazy,Affinitas Intimates,Affliction,Aftco,Agan Traders,Agave,Ahaarya,Aimee Gowns,Akademiks,Akomplice,Alan Sloane,Alex Cannon,Alex Evenings,Alex Stevens,Alexander Del Rossa,Alexander Julian,Alfani,Alfred Dunner,Alia,Alice & Olivia,Alice & Trixie,Alivila.Y Fashion,Alki'i,Allegra K,Allen Allen,Aloha,Alpha Industries,Alpine Swiss,Alpinestars,Altamont,Alternative,Always Sunny In Philadelphia,Amanda Uprichard,Amazing Apparel,Ambiguous,AmeriBag,American Apparel,American Essentials,American Fighter,American Rag,Ames,Amethyst Jeans,Amicale,Analog,Andrew Christian,Andrew Marc,Anemone,Angelina,Angelina Hosiery,Angry Birds,Animal Planet,AnimalShirtsUSA,Anita,Anna-Kaci,Annabelle,Annalee + Hope,Anne Cole,Anne Klein,Annee Matthew,Annex Clothing,Antigua,Antique Rivet,Antonio Ansaldi,Anue,Anvil,Apparel,Apparel Force,Aqua,Aqua Sphere,Aquapro,Arbor,Arborwear,Arc'teryx,Ardyss,Arena,Argenti,Ariat,Aris A,Ark apparel,Armada,Armani,Arnette,Artex,Artist Merch,ArtsyClothingCompany,Aryn K,As U Wish,Ash City,Ashworth,Assets,Athena,Atlas,Atti Fashion,August Silk,Augusta,Austin Reed,Authentic Pigment,Avenged Sevenfold,Aventura,Avenue,Aviator,Aviators,Avital,AxParis,Axis,Ayurvastram,B. B. Jeans Fashion,BANDOLINO,BANDOLINOBLU,BB,BB Dakota,BBC,BBW Boutique,BCBGMAXAZRIA,BCBGeneration,BDI,BERLE,BG,BGSD,BH Medwear,BHPC By Miss London,BIG STAR,BIKINI LAB,BKE,BLOOMINGDALES,BOTANY 500,BUDSHOP,Baby Banz,Baby Be Mine,Baby'O Clothing Co.,Bacci,Back to Back,Badger,Bag Girls,Bailey,Bailey 44,Bajer,Bali,Ballin,Banana Republic,Band Merch,Bar III,Barbour,Barefoot Dreams,Barely There,Bargain Headbands,Barmah Hats,Barracuda,Basic,Baskit,Bass,Bathrobes Online,Bauer,Bayside Apparel,Beach Joy,Beach Native,Beach Rays,Beardski,Beauty Night,Beauty and the Beach Blue Label,Becca by Rebecca Virtue,BedHead,Belabumbum,Belevation,Bella,Bella Materna,BellaBand,Bellfield,Belly Armor,Belly Bandit,Belly Button,BellyBra,Belts.com,BeltsandStuds,Ben Davis,Ben Sherman,Bench,Benny's,Berek,Berkshire,Bertolini,Besame,Betsey Johnson,Betty Boop,Beverly Hills Basics,Beyond Yoga,Beza,Bianca NygÃ¥rd,Big Feet Pajama Co,Big Feet Pajama Co.,Bigmansland,Bikeraccess,Bikinimo Swimwear,Bill Blass,Bill's Khakis,Billabong,Biography Wear,BirthandBaby,Bitablue,Bjorn Borg,Blac Label,Black Clover,Black Diamond,Black Fuchsia,Black Market-Lowbrow,Black Web,Blancq-Olibet,Blanks,Blanks Plus,Blarney Woollen Mills,Bleu Rod Beattie,Blink Product Design,Bloom's Outlet,Bloomingdale's,Bloomingdale's Now,Blue Banana,Blue Crown,Blue Line,Blue Marlin,Blue Plate,Blue Q,Blue Sky Swimwear,Blue Star Inc,Blue Star Inc.,BluePrint,Blueprint,Bobi,Boca,Boca Classics,Boconi,Body Glove,Body Language Fashions,Body Trends,Body Wrap,Body Wrappers,Bohn,Bolle,Bolzano,BonWorth,Bonfire,Bonus,Bordeaux,Bosca,Boston Industrial,Botany 500,Bottoms Out,Boulder Creek,Boutique 9,Boxercraft,Bra Discs,Bradford Exchange,Brand Q,Brand Q Vest,Bravado,Bravado! Designs,Brave Soul,Braveman,Braza,Breast is Best,BridalPetticoat,Bridgedale,Briefly Stated,Briggs,Brighton,Bristols 6,Brixton,Broner,Brooklyn Industries,Brooks,Brooks Brothers,Browning,Bslingerie,Buckle Down,Buckwear,Bud Light,Buff,Buffalo,Buffalo by David Bitton,Bullhead,Bundle Monster,Bungalow,Burlington Socks,Burnside,Burton,Bus Stop,Buxton,C & C California,C-IN2,C-Panty,C. Luce,C.C. Exclusives,C1RCA,CANYON GUIDE,CARRAIG DONN KNITWEAR,CASE IH, ...

# %%
altered_query.client_id = None
altered_query.id = None

# %%
#Option a. Run inline query. This is the simplest option for just getting the data now.
#This should return your newly filtered data from Look #2
response = sdk.run_inline_query(body=altered_query, result_format="json")
print(response)
# Out:
# [{"users.name":"Aaron Atkins","users.age":22},
# {"users.name":"Aaron Brush","users.age":52},
# {"users.name":"Aaron Collado","users.age":30},
# {"users.name":"Aaron Delossantos","users.age":28},
# {"users.name":"Aaron Fletcher","users.age":93},
# {"users.name":"Aaron Hudgens","users.age":16},
# {"users.name":"Aaron Lawrence","users.age":72},
# {"users.name":"Aaron Malley","users.age":72},
# {"users.name":"Aaron Mirabal","users.age":16},
# {"users.name":"Aaron Mosley","users.age":44},
# {"users.name":"Aaron Myers","users.age":58},
# {"users.name":"Aaron Rader","users.age":12},
# {"users.name":"Aaron Swafford","users.age":46},
# {"users.name":"Aaron Thomas","users.age":41},
# {"users.name":"Abbie Chun","users.age":46},
# {"users.name":"Abbie Hance","users.age":12},
# {"users.name":"Ada Canales","users.age":28},
# {"users.name":"Ada Hall","users.age":48},
# {"users.name":"Adam Castillo","users.age":88},
# {"users.name":"Adam Day","users.age":14},
# {"users.name":"Adam Dufour","users.age":57},
# {"users.name":"Adam Hodges","users.age":53},
# {"users.name":"Adam Jensen","users.age":12},
# {"users.name":"Adam Moreno","users.age":58},
# {"users.name":"Adam Munguia","users.age":12},
# {"users.name":"Adam Pardo","users.age":44},
# {"users.name":"Adam Polk","users.age":14},
# {"users.name":"Adam Purtell","users.age":64},
# {"users.name":"Adam Smith","users.age":62},
# {"users.name":"Adam Warner","users.age":47},
# {"users.name":"Adam Winslow","users.age":67},
# {"users.name":"Addie Downey","users.age":12},
# {"users.name":"Adelaide Feller","users.age":41},
# {"users.name":"Adelaide Krum","users.age":54},
# {"users.name":"Adele Anglin","users.age":37},
# {"users.name":"Adeline Griffith","users.age":42},
# {"users.name":"Adella Howard","users.age":38},
# {"users.name":"Adria Greenwood","users.age":46},
# {"users.name":"Adrian Freeman","users.age":41},
# {"users.name":"Adrian Gross","users.age":44},
# {"users.name":"Adrian Morabito","users.age":37},
# {"users.name":"Adrian Small","users.age":59},
# {"users.name":"Adrian Ware","users.age":44},
# {"users.name":"Adriana Weber","users.age":56},
# {"users.name":"Adrienne Obrien","users.age":64},
# {"users.name":"Agnes Casey","users.age":63},
# {"users.name":"Agnes Hague","users.age":39},
# {"users.name":"Agnes Solis","users.age":14},
# {"users.name":"Agnes Vargas","users.age":74},
# {"users.name":"Agnes Williams","users.age":37},
# {"users.name":"Agustin Lingerfelt","users.age":14},
# {"users.name":"Ahmed Bradley","users.age":26},
# {"users.name":"Aida Andrews","users.age":42},
# {"users.name":"Aida Britten","users.age":23},
# {"users.name":"Aida Jones","users.age":12},
# {"users.name":"Al Aaron","users.age":51},
# {"users.name":"Alan Brooks","users.age":16},
# {"users.name":"Alan Gallegos","users.age":37},
# {"users.name":"Alan Garner","users.age":14},
# {"users.name":"Alan Gibson","users.age":16},
# {"users.name":"Alan Lassiter","users.age":46},
# {"users.name":"Alan Manning","users.age":43},
# {"users.name":"Alan Rabinowitz","users.age":12},
# {"users.name":"Alan Rogers","users.age":14},
# {"users.name":"Alan Tarbell","users.age":12},
# {"users.name":"Alana Newell","users.age":70},
# {"users.name":"Albert Blake","users.age":14},
# {"users.name":"Albert Carlson","users.age":49},
# {"users.name":"Albert Caron","users.age":34},
# {"users.name":"Albert Garcia","users.age":98},
# {"users.name":"Albert Hollander","users.age":38},
# {"users.name":"Albert Kelley","users.age":51},
# {"users.name":"Albert Kelly","users.age":43},
# {"users.name":"Albert King","users.age":44},
# {"users.name":"Albert Mcnally","users.age":72},
# {"users.name":"Albert Pardue","users.age":46},
# {"users.name":"Albert Paul","users.age":64},
# {"users.name":"Albert Ronan","users.age":101},
# {"users.name":"Albert Salazar","users.age":37},
# {"users.name":"Albert Sanders","users.age":53},
# {"users.name":"Alberta Fenn","users.age":12},
# {"users.name":"Alberta Lee","users.age":52},
# {"users.name":"Alberta Weight","users.age":48},
# {"users.name":"Alberta Williams","users.age":64},
# {"users.name":"Alberto Calhoun","users.age":43},
# {"users.name":"Alberto Valladares","users.age":14},
# {"users.name":"Alejandra Cates","users.age":14},
# {"users.name":"Alejandra Ortega","users.age":36},
# {"users.name":"Alejandra Rothschild","users.age":27},
# {"users.name":"Alejandro Lopez","users.age":79},
# {"users.name":"Alejandro Tate","users.age":42},
# {"users.name":"Alena Tucker","users.age":12},
# {"users.name":"Alesha Walls","users.age":14},
# {"users.name":"Aleta Hill","users.age":16},
# {"users.name":"Aleta Holbrook","users.age":12},
# {"users.name":"Aletha Marquez","users.age":46},
# {"users.name":"Alex Johnson","users.age":16},
# {"users.name":"Alexa Phillips","users.age":14},
# {"users.name":"Alexander Bullock","users.age":21},
# {"users.name":"Alexander Felix","users.age":42},
# {"users.name":"Alexander Louden","users.age":19},
# {"users.name":"Alexander Palladino","users.age":12},
# {"users.name":"Alexander Rivera","users.age":16},
# {"users.name":"Alexandra Mcelveen","users.age":33},
# {"users.name":"Alexandra Scott","users.age":42},
# {"users.name":"Alexis Jones","users.age":41},
# {"users.name":"Alexis Szabo","users.age":63},
# {"users.name":"Alexis Williams","users.age":48},
# {"users.name":"Alfonso Allen","users.age":39},
# {"users.name":"Alfonso Fernandez","users.age":16},
# {"users.name":"Alfonso Gross","users.age":73},
# {"users.name":"Alfonso Simpkins","users.age":47},
# {"users.name":"Alfonzo Alvarez","users.age":61},
# {"users.name":"Alfred Auerbach","users.age":14},
# {"users.name":"Alfred Briggs","users.age":27},
# {"users.name":"Alfred Matranga","users.age":42},
# {"users.name":"Alfred Murdoch","users.age":25},
# {"users.name":"Alfred Skinner","users.age":41},
# {"users.name":"Alfred Taylor","users.age":16},
# {"users.name":"Alfredo Perez","users.age":18},
# {"users.name":"Alfredo Smith","users.age":53},
# {"users.name":"Ali Mueller","users.age":87},
# {"users.name":"Alice Arrington","users.age":46},
# {"users.name":"Alice Crowe","users.age":73},
# {"users.name":"Alice Gustafson","users.age":16},
# {"users.name":"Alice Hackler","users.age":72},
# {"users.name":"Alice Hernandez","users.age":16},
# {"users.name":"Alice Hisey","users.age":14},
# {"users.name":"Alice Hughes","users.age":43},
# {"users.name":"Alice Kane","users.age":61},
# {"users.name":"Alice Levy","users.age":44},
# {"users.name":"Alice Lundy","users.age":42},
# {"users.name":"Alice Medina","users.age":62},
# {"users.name":"Alice Normand","users.age":54},
# {"users.name":"Alice Parker","users.age":41},
# {"users.name":"Alice Schaeffer","users.age":38},
# {"users.name":"Alice Stephens","users.age":22},
# {"users.name":"Alice Theis","users.age":59},
# {"users.name":"Alice Thomas","users.age":47},
# {"users.name":"Alice Tocco","users.age":43},
# {"users.name":"Alice Welch","users.age":14},
# {"users.name":"Alicia Botsford","users.age":47},
# {"users.name":"Alicia Castrejon","users.age":36},
# {"users.name":"Alicia Franks","users.age":19},
# {"users.name":"Alicia Johnson","users.age":16},
# {"users.name":"Alicia Kiser","users.age":59},
# {"users.name":"Alicia Lewis","users.age":38},
# {"users.name":"Alicia Mcneil","users.age":16},
# {"users.name":"Alicia Ruiz","users.age":14},
# {"users.name":"Alisa Martin","users.age":28},
# {"users.name":"Alisha Callaway","users.age":14},
# {"users.name":"Alisha Green","users.age":41},
# {"users.name":"Alison Dover","users.age":42},
# {"users.name":"Alison Worcester","users.age":53},
# {"users.name":"Alissa Lopez","users.age":42},
# {"users.name":"Allan Newsom","users.age":48},
# {"users.name":"Allan West","users.age":42},
# {"users.name":"Allen Brown","users.age":39},
# {"users.name":"Allen Lewis","users.age":14},
# {"users.name":"Allen Novick","users.age":61},
# {"users.name":"Allen Price","users.age":39},
# {"users.name":"Allen Sanchez","users.age":25},
# {"users.name":"Allen White","users.age":48},
# {"users.name":"Allena Steffes","users.age":48},
# {"users.name":"Allie Wininger","users.age":47},
# {"users.name":"Allie Young","users.age":53},
# {"users.name":"Allison Mansour","users.age":62},
# {"users.name":"Allison Page","users.age":43},
# {"users.name":"Alma Anderson","users.age":42},
# {"users.name":"Alma Birdsong","users.age":14},
# {"users.name":"Alma Campbell","users.age":39},
# {"users.name":"Alma Gregg","users.age":56},
# {"users.name":"Alma Huffman","users.age":43},
# {"users.name":"Alma Jordan","users.age":47},
# {"users.name":"Alma Young","users.age":62},
# {"users.name":"Almeda Palmer","users.age":47},
# {"users.name":"Alonzo Hitchcock","users.age":16},
# {"users.name":"Alonzo Kelly","users.age":25},
# {"users.name":"Alpha Decker","users.age":58},
# {"users.name":"Alphonso Tracy","users.age":14},
# {"users.name":"Alta Daley","users.age":46},
# {"users.name":"Alta Saiz","users.age":12},
# {"users.name":"Altagracia Franklin","users.age":52},
# {"users.name":"Altagracia Pitcher","users.age":51},
# {"users.name":"Alton Ahearn","users.age":20},
# {"users.name":"Alton Wiley","users.age":36},
# {"users.name":"Alva Nowak","users.age":86},
# {"users.name":"Alvaro Carlson","users.age":83},
# {"users.name":"Alvaro Foos","users.age":51},
# {"users.name":"Alvaro Scott","users.age":27},
# {"users.name":"Alvin Birkland","users.age":16},
# {"users.name":"Alvin Lewis","users.age":63},
# {"users.name":"Alyce Campbell","users.age":38},
# {"users.name":"Alyce Winters","users.age":59},
# {"users.name":"Amado Chen","users.age":58},
# {"users.name":"Amanda Anderson","users.age":64},
# {"users.name":"Amanda Blackshear","users.age":39},
# {"users.name":"Amanda Coleman","users.age":57},
# {"users.name":"Amanda Coleman","users.age":29},
# {"users.name":"Amanda Conklin","users.age":56},
# {"users.name":"Amanda Delaney","users.age":38},
# {"users.name":"Amanda Donnelly","users.age":43},
# {"users.name":"Amanda Estrada","users.age":69},
# {"users.name":"Amanda Howard","users.age":24},
# {"users.name":"Amanda Ibarra","users.age":12},
# {"users.name":"Amanda Jones","users.age":16},
# {"users.name":"Amanda Ledbetter","users.age":44},
# {"users.name":"Amanda Mcgovern","users.age":12},
# {"users.name":"Amanda Pruitt","users.age":16},
# {"users.name":"Amanda Sanders","users.age":12},
# {"users.name":"Amanda Taylor","users.age":14},
# {"users.name":"Amanda Tucker","users.age":16},
# {"users.name":"Amanda Wells","users.age":52},
# {"users.name":"Amanda Welsh","users.age":67},
# {"users.name":"Amanda Wilson","users.age":38},
# {"users.name":"Amber Crawford","users.age":14},
# {"users.name":"Amber Guss","users.age":24},
# {"users.name":"Amber Williams","users.age":36},
# {"users.name":"Amelia Robins","users.age":44},
# {"users.name":"Amelia Stallworth","users.age":14},
# {"users.name":"America Williams","users.age":39},
# {"users.name":"Amy Adams","users.age":44},
# {"users.name":"Amy Alvarez","users.age":44},
# {"users.name":"Amy Ayala","users.age":53},
# {"users.name":"Amy Barnwell","users.age":44},
# {"users.name":"Amy Bouldin","users.age":26},
# {"users.name":"Amy Castle","users.age":61},
# {"users.name":"Amy Durazo","users.age":44},
# {"users.name":"Amy Fischer","users.age":46},
# {"users.name":"Amy Fowler","users.age":100},
# {"users.name":"Amy Freeman","users.age":62},
# {"users.name":"Amy Garman","users.age":42},
# {"users.name":"Amy Hinojosa","users.age":34},
# {"users.name":"Amy Houck","users.age":71},
# {"users.name":"Amy Johnson","users.age":56},
# {"users.name":"Amy Kennedy","users.age":16},
# {"users.name":"Amy Mosher","users.age":46},
# {"users.name":"Amy Murray","users.age":16},
# {"users.name":"Amy Noll","users.age":12},
# {"users.name":"Amy Rose","users.age":62},
# {"users.name":"Amy Seiler","users.age":52},
# {"users.name":"Amy Smalls","users.age":47},
# {"users.name":"Amy Stribling","users.age":82},
# {"users.name":"Amy Varney","users.age":66},
# {"users.name":"Amy Walker","users.age":12},
# {"users.name":"Amy Williams","users.age":48},
# {"users.name":"Ana Bates","users.age":49},
# {"users.name":"Ana Dillard","users.age":16},
# {"users.name":"Ana Fast","users.age":12},
# {"users.name":"Ana Ludwig","users.age":54},
# {"users.name":"Ana Pinckney","users.age":47},
# {"users.name":"Ana Thomas","users.age":42},
# {"users.name":"Andra Dailey","users.age":39},
# {"users.name":"Andre Allen","users.age":79},
# {"users.name":"Andre Cammack","users.age":26},
# {"users.name":"Andre Nicholson","users.age":46},
# {"users.name":"Andre Rosin","users.age":89},
# {"users.name":"Andre Stone","users.age":12},
# {"users.name":"Andrea Arakaki","users.age":49},
# {"users.name":"Andrea Burkett","users.age":14},
# {"users.name":"Andrea Frank","users.age":39},
# {"users.name":"Andrea Gibson","users.age":14},
# {"users.name":"Andrea Keith","users.age":42},
# {"users.name":"Andrea Noble","users.age":38},
# {"users.name":"Andrea Scott","users.age":30},
# {"users.name":"Andrea Simmons","users.age":46},
# {"users.name":"Andres Newkirk","users.age":42},
# {"users.name":"Andres Otero","users.age":16},
# {"users.name":"Andres Williams","users.age":37},
# {"users.name":"Andrew Alford","users.age":12},
# {"users.name":"Andrew Barber","users.age":72},
# {"users.name":"Andrew Belanger","users.age":48},
# {"users.name":"Andrew French","users.age":27},
# {"users.name":"Andrew Graham","users.age":37},
# {"users.name":"Andrew Hasse","users.age":12},
# {"users.name":"Andrew Hill","users.age":12},
# {"users.name":"Andrew Jackson","users.age":58},
# {"users.name":"Andrew Kahler","users.age":16},
# {"users.name":"Andrew Kendall","users.age":16},
# {"users.name":"Andrew Lee","users.age":26},
# {"users.name":"Andrew Moreno","users.age":44},
# {"users.name":"Andrew Pinon","users.age":54},
# {"users.name":"Andrew Plunkett","users.age":24},
# {"users.name":"Andrew Reichard","users.age":48},
# {"users.name":"Andrew Ruben","users.age":54},
# {"users.name":"Andrew Smith","users.age":37},
# {"users.name":"Andrew Spivey","users.age":41},
# {"users.name":"Andrew Stephen","users.age":52},
# {"users.name":"Andrew Thompson","users.age":56},
# {"users.name":"Andrew Torrez","users.age":42},
# {"users.name":"Andria Jones","users.age":56},
# {"users.name":"Andy Miller","users.age":56},
# {"users.name":"Andy Padilla","users.age":57},
# {"users.name":"Angel Bengtson","users.age":12},
# {"users.name":"Angela Abraham","users.age":43},
# {"users.name":"Angela Broughton","users.age":14},
# {"users.name":"Angela Candelaria","users.age":39},
# {"users.name":"Angela Diaz","users.age":64},
# {"users.name":"Angela Dieter","users.age":44},
# {"users.name":"Angela Draper","users.age":12},
# {"users.name":"Angela Granado","users.age":61},
# {"users.name":"Angela Klinger","users.age":41},
# {"users.name":"Angela Lacy","users.age":66},
# {"users.name":"Angela Lewis","users.age":34},
# {"users.name":"Angela Lopez","users.age":56},
# {"users.name":"Angela Miller","users.age":37},
# {"users.name":"Angela Newberry","users.age":24},
# {"users.name":"Angela Owen","users.age":14},
# {"users.name":"Angela Page","users.age":14},
# {"users.name":"Angela Parham","users.age":42},
# {"users.name":"Angela Richardson","users.age":16},
# {"users.name":"Angela Shellenberger","users.age":16},
# {"users.name":"Angela Sheridan","users.age":32},
# {"users.name":"Angela Thorn","users.age":14},
# {"users.name":"Angele Rudder","users.age":25},
# {"users.name":"Angelika Sledge","users.age":32},
# {"users.name":"Angelina Baptiste","users.age":53},
# {"users.name":"Angelina Diaz","users.age":39},
# {"users.name":"Angelina Reid","users.age":16},
# {"users.name":"Angelina Torrez","users.age":12},
# {"users.name":"Angelo Roberts","users.age":14},
# {"users.name":"Angie Mccarthy","users.age":56},
# {"users.name":"Angie Shenk","users.age":16},
# {"users.name":"Anita Blaha","users.age":32},
# {"users.name":"Anita Dillard","users.age":38},
# {"users.name":"Anita Hartsock","users.age":38},
# {"users.name":"Anita Horne","users.age":16},
# {"users.name":"Anita Huerta","users.age":37},
# {"users.name":"Anita Martin","users.age":16},
# {"users.name":"Anita Mclaughlin","users.age":59},
# {"users.name":"Anita Pinkerton","users.age":12},
# {"users.name":"Anita Stevenson","users.age":53},
# {"users.name":"Anita Stock","users.age":51},
# {"users.name":"Anita Williams","users.age":16},
# {"users.name":"Anitra Davis","users.age":16},
# {"users.name":"Ann Barnett","users.age":16},
# {"users.name":"Ann Cranor","users.age":39},
# {"users.name":"Ann Deanda","users.age":16},
# {"users.name":"Ann Gutierrez","users.age":84},
# {"users.name":"Ann Hagan","users.age":38},
# {"users.name":"Ann Hockett","users.age":16},
# {"users.name":"Ann Lewis","users.age":39},
# {"users.name":"Ann Longworth","users.age":12},
# {"users.name":"Ann Marchese","users.age":20},
# {"users.name":"Ann Minton","users.age":12},
# {"users.name":"Ann Morales","users.age":48},
# {"users.name":"Ann Scharff","users.age":14},
# {"users.name":"Ann Sims","users.age":16},
# {"users.name":"Ann Smith","users.age":62},
# {"users.name":"Ann Tinkham","users.age":16},
# {"users.name":"Ann Walston","users.age":12},
# {"users.name":"Ann Wilson","users.age":46},
# {"users.name":"Anna Aderholt","users.age":14},
# {"users.name":"Anna Brooks","users.age":42},
# {"users.name":"Anna Criner","users.age":48},
# {"users.name":"Anna Gibbons","users.age":62},
# {"users.name":"Anna Grady","users.age":12},
# {"users.name":"Anna Hilton","users.age":14},
# {"users.name":"Anna Hollingsworth","users.age":33},
# {"users.name":"Anna Jacobs","users.age":37},
# {"users.name":"Anna Johnson","users.age":57},
# {"users.name":"Anna Leflore","users.age":48},
# {"users.name":"Anna Mcknight","users.age":12},
# {"users.name":"Anna Nally","users.age":14},
# {"users.name":"Anna Patterson","users.age":58},
# {"users.name":"Anna Piland","users.age":47},
# {"users.name":"Anna Quintero","users.age":12},
# {"users.name":"Anna Rodriguez","users.age":74},
# {"users.name":"Anna Smith","users.age":38},
# {"users.name":"Anna Stanley","users.age":43},
# {"users.name":"Anna Vollmer","users.age":39},
# {"users.name":"Annamae Quisenberry","users.age":41},
# {"users.name":"Annamae Wilkins","users.age":37},
# {"users.name":"Anne Banda","users.age":12},
# {"users.name":"Anne Branch","users.age":49},
# {"users.name":"Anne Goris","users.age":42},
# {"users.name":"Anne Gould","users.age":12},
# {"users.name":"Anne Johnson","users.age":12},
# {"users.name":"Anne Lee","users.age":48},
# {"users.name":"Anne Massey","users.age":12},
# {"users.name":"Anne Royalty","users.age":12},
# {"users.name":"Anne Stone","users.age":36},
# {"users.name":"Anne Taylor","users.age":52},
# {"users.name":"Anne Valenzuela","users.age":47},
# {"users.name":"Anne Woodley","users.age":43},
# {"users.name":"Annetta Griffing","users.age":59},
# {"users.name":"Annette Bacon","users.age":22},
# {"users.name":"Annette Macmillan","users.age":38},
# {"users.name":"Annette Russell","users.age":25},
# {"users.name":"Annette Velasquez","users.age":64},
# {"users.name":"Annie Andrews","users.age":32},
# {"users.name":"Annie Arbogast","users.age":36},
# {"users.name":"Annie Brady","users.age":74},
# {"users.name":"Annie Cade","users.age":16},
# {"users.name":"Annie Clemens","users.age":54},
# {"users.name":"Annie Jenkins","users.age":87},
# {"users.name":"Annie Johnson","users.age":63},
# {"users.name":"Annie Lemay","users.age":58},
# {"users.name":"Annie Maddox","users.age":59},
# {"users.name":"Annie Wood","users.age":12},
# {"users.name":"Annmarie Watson","users.age":38},
# {"users.name":"Anthony Baldwin","users.age":46},
# {"users.name":"Anthony Booker","users.age":16},
# {"users.name":"Anthony Burton","users.age":42},
# {"users.name":"Anthony Dennis","users.age":18},
# {"users.name":"Anthony Engebretson","users.age":16},
# {"users.name":"Anthony Hatchett","users.age":66},
# {"users.name":"Anthony Hill","users.age":36},
# {"users.name":"Anthony Hill","users.age":12},
# {"users.name":"Anthony Jozwiak","users.age":37},
# {"users.name":"Anthony Kane","users.age":12},
# {"users.name":"Anthony Lyons","users.age":33},
# {"users.name":"Anthony Merriman","users.age":14},
# {"users.name":"Anthony Miles","users.age":51},
# {"users.name":"Anthony Miller","users.age":53},
# {"users.name":"Anthony Mills","users.age":24},
# {"users.name":"Anthony Morris","users.age":64},
# {"users.name":"Anthony Russell","users.age":38},
# {"users.name":"Anthony Ryerson","users.age":32},
# {"users.name":"Anthony Stengel","users.age":48},
# {"users.name":"Anthony Tilley","users.age":33},
# {"users.name":"Anthony Walters","users.age":39},
# {"users.name":"Anthony Watson","users.age":57},
# {"users.name":"Anthony West","users.age":54},
# {"users.name":"Anthony Wilson","users.age":14},
# {"users.name":"Anthony Yap","users.age":38},
# {"users.name":"Antionette Morales","users.age":14},
# {"users.name":"Antoine Hanna","users.age":56},
# {"users.name":"Antoinette Cain","users.age":16},
# {"users.name":"Antoinette Livingston","users.age":64},
# {"users.name":"Antoinette Waddle","users.age":56},
# {"users.name":"Antonia Cano","users.age":48},
# {"users.name":"Antonia Meyers","users.age":42},
# {"users.name":"Antonietta Richardson","users.age":38},
# {"users.name":"Antonina Brown","users.age":39},
# {"users.name":"Antonio Brand","users.age":64},
# {"users.name":"Antonio Dominguez","users.age":14},
# {"users.name":"Antonio Dougherty","users.age":16},
# {"users.name":"Antonio Field","users.age":16},
# {"users.name":"Antonio Nunez","users.age":41},
# {"users.name":"Antonio Pitre","users.age":16},
# {"users.name":"Antonio Thompson","users.age":79},
# {"users.name":"Antonio Thrower","users.age":14},
# {"users.name":"April Cofer","users.age":68},
# {"users.name":"April Peavey","users.age":48},
# {"users.name":"April Perry","users.age":53},
# {"users.name":"April Slaughter","users.age":48},
# {"users.name":"April Underwood","users.age":39},
# {"users.name":"Araceli Aguilar","users.age":74},
# {"users.name":"Archie Deforge","users.age":46},
# {"users.name":"Archie Murphy","users.age":12},
# {"users.name":"Archie Willis","users.age":12},
# {"users.name":"Arden Chong","users.age":57},
# {"users.name":"Ardith Augustine","users.age":44},
# {"users.name":"Aretha Stark","users.age":36},
# {"users.name":"Arla Costello","users.age":16},
# {"users.name":"Arleen Cunningham","users.age":46},
# {"users.name":"Arleen Leonard","users.age":38},
# {"users.name":"Arlene Alford","users.age":12},
# {"users.name":"Arlene Martinez","users.age":43},
# {"users.name":"Arlene Mosley","users.age":14},
# {"users.name":"Arlene Prater","users.age":39},
# {"users.name":"Arlene Taylor","users.age":41},
# {"users.name":"Arlene Williams","users.age":53},
# {"users.name":"Arlie Hansen","users.age":37},
# {"users.name":"Armand Almazan","users.age":80},
# {"users.name":"Armand Drake","users.age":48},
# {"users.name":"Armanda Salgado","users.age":61},
# {"users.name":"Armando Harvey","users.age":59},
# {"users.name":"Arnold Blake","users.age":16},
# {"users.name":"Arnold Turner","users.age":39},
# {"users.name":"Arthur Anderson","users.age":16},
# {"users.name":"Arthur Bailey","users.age":74},
# {"users.name":"Arthur Delgado","users.age":12},
# {"users.name":"Arthur Gravitt","users.age":49},
# {"users.name":"Arthur Hamilton","users.age":49},
# {"users.name":"Arthur Murray","users.age":16},
# {"users.name":"Arthur Nemeth","users.age":54},
# {"users.name":"Arthur Newcomb","users.age":14},
# {"users.name":"Arthur Pugh","users.age":57},
# {"users.name":"Arthur Rogue","users.age":62},
# {"users.name":"Arthur Rojas","users.age":39},
# {"users.name":"Arturo Rodriguez","users.age":12},
# {"users.name":"Ashlee Dunning","users.age":58},
# {"users.name":"Ashley Beltran","users.age":14},
# {"users.name":"Ashley Buxton","users.age":19},
# {"users.name":"Ashley Cross","users.age":38},
# {"users.name":"Ashley Foote","users.age":39},
# {"users.name":"Ashley Fortner","users.age":83},
# {"users.name":"Ashley Holland","users.age":14},
# {"users.name":"Ashley James","users.age":12},
# {"users.name":"Ashley Lutz","users.age":16},
# {"users.name":"Ashley Macdonald","users.age":57},
# {"users.name":"Ashley Oneill","users.age":71},
# {"users.name":"Ashley Poe","users.age":52},
# {"users.name":"Ashley Potts","users.age":16},
# {"users.name":"Ashley Regalado","users.age":28},
# {"users.name":"Ashley Ross","users.age":23},
# {"users.name":"Ashley Rowland","users.age":12},
# {"users.name":"Ashley Schaefer","users.age":36}]

# %%
#Option b. Creating a brand new query object, then running that query from the ID.
#You might want to do this if you're planning to run the query asynchronously using create_query_task.
new_query = sdk.create_query(body=altered_query)
response = sdk.run_query(query_id=new_query.id, result_format="json")
print(response)
# Out:
# [{"looker_error":"SQL Error: driver.new.connect returned nil: probably bad JDBC connection string"}]

# %%
new_query = sdk.create_query(body=altered_query)
response = sdk.run_query(query_id=new_query.id, result_format="json")
print(response)
# Out:
# [{"looker_error":"SQL Error: driver.new.connect returned nil: probably bad JDBC connection string"}]

# %%
pip install xlsxwriter
# Out:
# Collecting xlsxwriter
#   Downloading XlsxWriter-3.0.3-py3-none-any.whl (149 kB)
#      |████████████████████████████████| 149 kB 12.7 MB/s
# Installing collected packages: xlsxwriter
# Successfully installed xlsxwriter-3.0.3

# %%
import glob

import pandas as pd

csv_folder = './dashboard-agency_dashboard/' + '*.csv'
excel_file = './exporte_excel.xlsx'

excel_writer = pd.ExcelWriter(excel_file, engine='xlsxwriter')

for file in glob.iglob(csv_folder, recursive=True):
    df = pd.read_csv(file)
    df.to_excel(excel_writer, sheet_name=file.split('\\')[-1], index=False)


excel_writer.save()
print('Task Completed')
# Out:
# Task Completed

# %%
import glob

import pandas as pd

csv_folder = 'C:/Users/priyanka.g/Desktop/pythoncsvlooks/' + '*.csv'
excel_file = './pythonlooks_excel.xlsx'

excel_writer = pd.ExcelWriter(excel_file, engine='xlsxwriter')

for file in glob.iglob(csv_folder, recursive=True):
    df = pd.read_csv(file)
    df.to_excel(excel_writer, sheet_name=file.split('\\')[-1], index=False)


excel_writer.save()
print('Task Completed')
# Out:
# Task Completed

# %%
pip install pandas openpyxl
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (1.3.5)
# Requirement already satisfied: openpyxl in /usr/local/lib/python3.7/dist-packages (3.0.9)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.7/dist-packages (from pandas) (1.21.5)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas) (1.15.0)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.7/dist-packages (from openpyxl) (1.1.0)

# %%
import pandas as pd

# %%
df =pd.read_json("pythonlook.json_label")

# %%
df.to_excel("results.xlsx")

# %%
df =pd.read_json("pythonlookusers.json_label")

# %%
df.to_excel("saas.xlsx")

# %%
import glob

import pandas as pd

csv_folder = './dashboard-agency_dashboard/' + '*.csv'
excel_file = './export_excel.xlsx'

excel_writer = pd.ExcelWriter(excel_file, engine='xlsxwriter')

for file in glob.iglob(csv_folder, recursive=True):
    df = pd.read_csv(file)
    df.to_excel(excel_writer, sheet_name=file.split('\\')[-1], index=False)


excel_writer.save()
print('Task Completed')

# %%
import sys
import textwrap
import time

import looker_sdk
from looker_sdk import models

sdk = looker_sdk.init31("../../looker.ini")

def main():
    look_title = sys.argv[1] if len(sys.argv) > 1 else ""
    image_width = int(sys.argv[2]) if len(sys.argv) > 2 else 545
    image_height = int(sys.argv[3]) if len(sys.argv) > 3 else 842
    image_format = sys.argv[4] if len(sys.argv) > 4 else "png"

    if not look_title:
        raise Exception(
            textwrap.dedent(
                """
                Please provide: <lookTitle> [<img_width>] [<img_height>] [<img_format>]
                    img_width defaults to 545
                    img_height defaults to 842
                    img_format defaults to 'png'"""
            )
        )

    look = get_look(look_title)
    download_look(look, image_format="json", image_width=545, image_height=842)


def get_look(title: str) -> models.Look:
    title = title.lower()
    look = next(iter(sdk.search_looks(title=title)), None)
    if not look:
        raise Exception(f"look '{title}' was not found")
    return look


def download_look(look: models.Look, result_format: str, width: int, height: int):
    """Download specified look as png/jpg"""
    id = int(look.id)
    task = sdk.create_look_render_task(id, result_format, width, height,)

    if not (task and task.id):
        raise sdk_exceptions.RenderTaskError(
            f"Could not create a render task for '{look.title}'"
        )

    # poll the render task until it completes
    elapsed = 0.0
    delay = 0.5  # wait .5 seconds
    while True:
        poll = sdk.render_task(task.id)
        if poll.status == "failure":
            print(poll)
            raise Exception(f"Render failed for '{look.title}'")
        elif poll.status == "success":
            break
        time.sleep(delay)
        elapsed += delay
    print(f"Render task completed in {elapsed} seconds")

    result = sdk.render_task_results(task.id)
    filename = f"{look.title}.{result_format}"
    with open(filename, "wb") as f:
        f.write(result)
    print(f"Look saved to '{filename}'")

# %%
pip install pyenv
# Out:
# Collecting pyenv
#   Downloading pyenv-0.0.1.tar.gz (1.4 kB)
# Building wheels for collected packages: pyenv
#   Building wheel for pyenv (setup.py) ... error
#   ERROR: Failed building wheel for pyenv
#   Running setup.py clean for pyenv
# Failed to build pyenv
# Installing collected packages: pyenv
#     Running setup.py install for pyenv ... error
# ERROR: Command errored out with exit status 1: /usr/bin/python3 -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/tmp/pip-install-qq4rfv12/pyenv_fc4d240ce5b84fe3b6e1171367019f5c/setup.py'"'"'; __file__='"'"'/tmp/pip-install-qq4rfv12/pyenv_fc4d240ce5b84fe3b6e1171367019f5c/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record /tmp/pip-record-0bflu799/install-record.txt --single-version-externally-managed --compile --install-headers /usr/local/include/python3.7/pyenv Check the logs for full command output.
